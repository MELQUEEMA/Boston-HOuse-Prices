# %% [markdown]
# <a href="https://colab.research.google.com/github/MELQUEEMA/Boston-HOuse-Prices/blob/main/pandas_Essential_Training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df =pd.read_csv('/content/olympics.csv',delimiter=',')

# %%
df
# Out:
#           City  Edition  ... Event_gender   Medal
# 0       Athens     1896  ...            M    Gold
# 1       Athens     1896  ...            M  Silver
# 2       Athens     1896  ...            M  Bronze
# 3       Athens     1896  ...            M    Gold
# 4       Athens     1896  ...            M  Silver
# ...        ...      ...  ...          ...     ...
# 29211  Beijing     2008  ...            M  Silver
# 29212  Beijing     2008  ...            M  Bronze
# 29213  Beijing     2008  ...            M  Bronze
# 29214  Beijing     2008  ...            M    Gold
# 29215  Beijing     2008  ...            M  Silver
#
# [29216 rows x 10 columns]

# %%
t1=df['NOC']
type(t1)
# Out:
# pandas.core.series.Series

# %%
t2=df.NOC
type(t2)
# Out:
# pandas.core.series.Series

# %%
df[['City','Edition','Athlete','Medal']]
# Out:
#           City  Edition               Athlete   Medal
# 0       Athens     1896         HAJOS, Alfred    Gold
# 1       Athens     1896      HERSCHMANN, Otto  Silver
# 2       Athens     1896     DRIVAS, Dimitrios  Bronze
# 3       Athens     1896    MALOKINIS, Ioannis    Gold
# 4       Athens     1896    CHASAPIS, Spiridon  Silver
# ...        ...      ...                   ...     ...
# 29211  Beijing     2008        ENGLICH, Mirko  Silver
# 29212  Beijing     2008  MIZGAITIS, Mindaugas  Bronze
# 29213  Beijing     2008       PATRIKEEV, Yuri  Bronze
# 29214  Beijing     2008         LOPEZ, Mijain    Gold
# 29215  Beijing     2008        BAROEV, Khasan  Silver
#
# [29216 rows x 4 columns]

# %%
type(df[['City','Edition','Athlete','Medal']])
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape[1]
# Out:
# 10

# %%
df.head(3)
# Out:
#      City  Edition     Sport  ...                       Event Event_gender   Medal
# 0  Athens     1896  Aquatics  ...              100m freestyle            M    Gold
# 1  Athens     1896  Aquatics  ...              100m freestyle            M  Silver
# 2  Athens     1896  Aquatics  ...  100m freestyle for sailors            M  Bronze
#
# [3 rows x 10 columns]

# %%
df.tail(3)
# Out:
#           City  Edition      Sport  ...       Event Event_gender   Medal
# 29213  Beijing     2008  Wrestling  ...  96 - 120kg            M  Bronze
# 29214  Beijing     2008  Wrestling  ...  96 - 120kg            M    Gold
# 29215  Beijing     2008  Wrestling  ...  96 - 120kg            M  Silver
#
# [3 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29216 entries, 0 to 29215
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   City          29216 non-null  object
#  1   Edition       29216 non-null  int64
#  2   Sport         29216 non-null  object
#  3   Discipline    29216 non-null  object
#  4   Athlete       29216 non-null  object
#  5   NOC           29216 non-null  object
#  6   Gender        29216 non-null  object
#  7   Event         29216 non-null  object
#  8   Event_gender  29216 non-null  object
#  9   Medal         29216 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 2.2+ MB

# %%
df['Edition'].value_counts()
# Out:
# 2008    2042
# 2000    2015
# 2004    1998
# 1996    1859
# 1992    1705
# 1988    1546
# 1984    1459
# 1980    1387
# 1976    1305
# 1920    1298
# 1972    1185
# 1968    1031
# 1964    1010
# 1952     889
# 1912     885
# 1956     885
# 1924     884
# 1960     882
# 1936     875
# 1948     814
# 1908     804
# 1928     710
# 1932     615
# 1900     512
# 1904     470
# 1896     151
# Name: Edition, dtype: int64

# %%
ath = df.Athlete.sort_values(0)

# %%
df[['Athlete'].str.contains('Jesse')]
# Out:
#                         City  Edition  ... Event_gender   Medal
# 1522                  London     1908  ...            M    Gold
# 1773                  London     1908  ...            M  Bronze
# 6427                  Berlin     1936  ...            M    Gold
# 6439                  Berlin     1936  ...            M    Gold
# 6456                  Berlin     1936  ...            M    Gold
# 6523                  Berlin     1936  ...            M    Gold
# 7444                  London     1948  ...            M    Gold
# 9070   Melbourne / Stockholm     1956  ...            M    Gold
# 11462                  Tokyo     1964  ...            M  Silver
# 13113                 Munich     1972  ...            M  Bronze
# 26519                 Athens     2004  ...            M  Silver
# 27479                Beijing     2008  ...            M  Silver
# 28065                Beijing     2008  ...            M  Bronze
#
# [13 rows x 10 columns]

# %%
df[df['Athlete']=='OWENS, Jesse']
# Out:
#         City  Edition      Sport  ...         Event Event_gender Medal
# 6427  Berlin     1936  Athletics  ...          100m            M  Gold
# 6439  Berlin     1936  Athletics  ...          200m            M  Gold
# 6456  Berlin     1936  Athletics  ...  4x100m relay            M  Gold
# 6523  Berlin     1936  Athletics  ...     long jump            M  Gold
#
# [4 rows x 10 columns]

# %%
badminton = df[(df['Medal']=='Gold')& (df['Sport']=='Badminton') &(df['Gender']=='Men')&(df['Event']=='singles')]

# %%
badminton_sorted_by_name=badminton.sort_values('Athlete')

# %%
badminton_sorted_by_name
# Out:
#             City  Edition      Sport  ...    Event Event_gender Medal
# 20045  Barcelona     1992  Badminton  ...  singles            M  Gold
# 25734     Athens     2004  Badminton  ...  singles            M  Gold
# 21787    Atlanta     1996  Badminton  ...  singles            M  Gold
# 23717     Sydney     2000  Badminton  ...  singles            M  Gold
# 27741    Beijing     2008  Badminton  ...  singles            M  Gold
#
# [5 rows x 10 columns]

# %%
country_medal=df[(df['Edition']>=1984) & (df['Edition']<=2008)]

# %%
sorted_country_medal=country_medal.sort_values('NOC')

# %%
sorted_country_medal.NOC.value_counts()
# Out:
# USA    1837
# AUS     762
# GER     691
# CHN     679
# RUS     638
#        ...
# MRI       1
# URU       1
# TOG       1
# ERI       1
# BAR       1
# Name: NOC, Length: 124, dtype: int64

# %%
sprint=df[(df['Medal']=='Gold')&(df['Event']=='100m')&(df.Gender=='Men')]

# %%
sorted_sprint=sprint.sort_values('Edition',ascending=False)

# %%
sorted_sprint[['City','Edition','Athlete','NOC']]
# Out:
#                         City  Edition                Athlete  NOC
# 27552                Beijing     2008            BOLT, Usain  JAM
# 25539                 Athens     2004         GATLIN, Justin  USA
# 23521                 Sydney     2000        GREENE, Maurice  USA
# 21598                Atlanta     1996        BAILEY, Donovan  CAN
# 19859              Barcelona     1992      CHRISTIE, Linford  GBR
# 18284                  Seoul     1988            LEWIS, Carl  USA
# 16794            Los Angeles     1984            LEWIS, Carl  USA
# 15374                 Moscow     1980           WELLS, Allan  GBR
# 14069               Montreal     1976       CRAWFORD, Hasely  TRI
# 12902                 Munich     1972         BORZOV, Valery  URS
# 11865                 Mexico     1968       HINES, James Ray  USA
# 10823                  Tokyo     1964          HAYES, Robert  USA
# 9924                    Rome     1960            HARY, Armin  EUA
# ...

# %%
ED1 = df[df['Edition']==1896]

# %%
ED1.Sport.value_counts().plot()
plt.xticks(rotation=90)
plt.title('Sports in the first olympics',color='b')
plt.show()

# %%
ED1.Sport.value_counts().plot(kind='bar')
plt.xticks(rotation=90)
plt.title('Sports in the first olympics',color='b')
plt.show()

# %%
ED1.Sport.value_counts().plot(kind='barh')
plt.xticks(rotation=90)
plt.title('Sports in the first olympics',color='b')
plt.show()

# %%
plt.figure(figsize=(5,5))
ED1.Sport.value_counts().plot(kind='pie')

plt.title('Sports in the first olympics',color='b')
plt.show()

# %%
cgm=df[(df['Edition']==2008)& (df['NOC']=='CHN')].sort_values(by='Medal')

# %%
sns.countplot(x='Gender',data=cgm,palette='bwr')

# %%
cgm.Gender.value_counts().plot(kind='bar',figsize=(8,5),color='b');

# %%
sns.countplot(x='Medal',data=cgm,hue='Gender',palette='bwr',order=['Bronze','Silver','Gold'])

# %%
df.index[100]
# Out:
# 100

# %%
df_new = df

# %%
df_new.set_index('Athlete',inplace=True)

# %%
df_new.head()
# Out:
#                       City  Edition  ... Event_gender   Medal
# Athlete                              ...
# HAJOS, Alfred       Athens     1896  ...            M    Gold
# HERSCHMANN, Otto    Athens     1896  ...            M  Silver
# DRIVAS, Dimitrios   Athens     1896  ...            M  Bronze
# MALOKINIS, Ioannis  Athens     1896  ...            M    Gold
# CHASAPIS, Spiridon  Athens     1896  ...            M  Silver
#
# [5 rows x 9 columns]

# %%
df_new.reset_index(inplace=True)

# %%
df_new
# Out:
#                     Athlete     City  ...  Event_gender   Medal
# 0             HAJOS, Alfred   Athens  ...             M    Gold
# 1          HERSCHMANN, Otto   Athens  ...             M  Silver
# 2         DRIVAS, Dimitrios   Athens  ...             M  Bronze
# 3        MALOKINIS, Ioannis   Athens  ...             M    Gold
# 4        CHASAPIS, Spiridon   Athens  ...             M  Silver
# ...                     ...      ...  ...           ...     ...
# 29211        ENGLICH, Mirko  Beijing  ...             M  Silver
# 29212  MIZGAITIS, Mindaugas  Beijing  ...             M  Bronze
# 29213       PATRIKEEV, Yuri  Beijing  ...             M  Bronze
# 29214         LOPEZ, Mijain  Beijing  ...             M    Gold
# 29215        BAROEV, Khasan  Beijing  ...             M  Silver
#
# [29216 rows x 10 columns]

# %%
df_new.set_index('Athlete',inplace=True)

# %%
df_new
df
# Out:
#                         Athlete      City  ...  Event_gender   Medal
# 0                  AABYE, Edgar     Paris  ...             M    Gold
# 1         AALTONEN, Arvo Ossian   Antwerp  ...             M  Bronze
# 2         AALTONEN, Arvo Ossian   Antwerp  ...             M  Bronze
# 3      AALTONEN, Paavo Johannes    London  ...             M    Gold
# 4      AALTONEN, Paavo Johannes    London  ...             M    Gold
# ...                         ...       ...  ...           ...     ...
# 29211                ÖSTMO, Ole     Paris  ...             M  Bronze
# 29212                ÖSTMO, Ole     Paris  ...             M  Silver
# 29213                ÖSTMO, Ole     Paris  ...             M  Silver
# 29214                ÖSTMO, Ole     Paris  ...             M  Bronze
# 29215         ÖSTRAND, Per-Olof  Helsinki  ...             M  Bronze
#
# [29216 rows x 10 columns]

# %%
df_new.sort_index(inplace=True)

# %%
df.reset_index(inplace=True)

# %%
df[df['Athlete'].str.contains('BOLT')]
# Out:
#                             Athlete                   City  ...  Event_gender   Medal
# 2450                    BOLT, Usain                Beijing  ...             M    Gold
# 2451                    BOLT, Usain                Beijing  ...             M    Gold
# 2452                    BOLT, Usain                Beijing  ...             M    Gold
# 2453  BOLTENSTERN JR., Gustaf Adolf  Melbourne / Stockholm  ...             X    Gold
# 2454  BOLTENSTERN JR., Gustaf Adolf               Helsinki  ...             X    Gold
# 2455  BOLTENSTERN JR., Gustaf Adolf                 London  ...             X  Bronze
# 2456  BOLTENSTERN JR., Gustaf Adolf            Los Angeles  ...             X  Silver
# 2457      BOLTENSTERN, Gustaf-Adolf              Stockholm  ...             X  Silver
# 2458                 BOLTON, Ruthie                 Sydney  ...             W    Gold
# 2459                 BOLTON, Ruthie                Atlanta  ...             W    Gold
#
# [10 rows x 10 columns]

# %%
df_new =df.set_index('Athlete')

# %%
df_new.loc['BOLT, Usain']
# Out:
#                 City  Edition      Sport  ...         Event Event_gender Medal
# Athlete                                   ...
# BOLT, Usain  Beijing     2008  Athletics  ...          200m            M  Gold
# BOLT, Usain  Beijing     2008  Athletics  ...  4x100m relay            M  Gold
# BOLT, Usain  Beijing     2008  Athletics  ...          100m            M  Gold
#
# [3 rows x 9 columns]

# %%
df.head(10)
# Out:
#                     Athlete      City  ...  Event_gender   Medal
# 0              AABYE, Edgar     Paris  ...             M    Gold
# 1     AALTONEN, Arvo Ossian   Antwerp  ...             M  Bronze
# 2     AALTONEN, Arvo Ossian   Antwerp  ...             M  Bronze
# 3  AALTONEN, Paavo Johannes    London  ...             M    Gold
# 4  AALTONEN, Paavo Johannes    London  ...             M    Gold
# 5  AALTONEN, Paavo Johannes    London  ...             M    Gold
# 6  AALTONEN, Paavo Johannes    London  ...             M  Bronze
# 7  AALTONEN, Paavo Johannes  Helsinki  ...             M  Bronze
# 8          AAMODT, Ragnhild   Beijing  ...             W    Gold
# 9          AANING, Alf Lied   Antwerp  ...             M  Silver
#
# [10 rows x 10 columns]

# %%
df.iloc[[1700,2000,2254,15000]]
# Out:
#                       Athlete         City  ...  Event_gender   Medal
# 1700       BEKKEVOLD, Kristin       Sydney  ...             W    Gold
# 2000       BESSONOV, Vladimir       Moscow  ...             M  Bronze
# 2254   BLATNICK, Jeffrey Carl  Los Angeles  ...             M    Gold
# 15000        LISITSKY, Viktor        Tokyo  ...             M  Silver
#
# [4 rows x 10 columns]

# %%
df.iloc[1:6]
# Out:
#                     Athlete     City  ...  Event_gender   Medal
# 1     AALTONEN, Arvo Ossian  Antwerp  ...             M  Bronze
# 2     AALTONEN, Arvo Ossian  Antwerp  ...             M  Bronze
# 3  AALTONEN, Paavo Johannes   London  ...             M    Gold
# 4  AALTONEN, Paavo Johannes   London  ...             M    Gold
# 5  AALTONEN, Paavo Johannes   London  ...             M    Gold
#
# [5 rows x 10 columns]

# %%
df_medals = df.set_index('Medal')

# %%
df_gold = df_medals.loc['Gold']

# %%
df_gold.sort_values(by='NOC')
# Out:
#                     Athlete       City  ...                    Event Event_gender
# Medal                                   ...
# Gold    MORCELI, Nourredine    Atlanta  ...                    1500m            M
# Gold        SOLTANI, Hocine    Atlanta  ...  57 - 60kg (lightweight)            M
# Gold   MERAH-BENIDA, Nouria     Sydney  ...                    1500m            W
# Gold     BOULMERKA, Hassiba  Barcelona  ...                    1500m            W
# Gold       CRAIG, Robert R.     London  ...                    rugby            M
# ...                     ...        ...  ...                      ...          ...
# Gold       BENNETT, Charles      Paris  ...               5000m team            M
# Gold          TYSOE, Alfred      Paris  ...               5000m team            M
# Gold      RAWLINSON, Alfred      Paris  ...                     polo            M
# Gold           DIAZ, Manuel   St Louis  ...                foil team            M
# ...

# %%
df_gold.plot(kind='hist',figsize=(8,6));
plt.title('Number of gold Medals Over The Years ')
# Out:
# Text(0.5, 1.0, 'Number of gold Medals Over The Years ')

# %%
df.set_index('NOC',inplace=True)

# %%
plt.figure(figsize=(20,10))
sns.countplot(x='Edition',hue='Medal',data=df),
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f88322b4e90>,)

# %%
df['Edition'].value_counts().sort_index().plot(figsize=(10,5))
plt.title('Number Of Gold Medals Over The Years')

# %%
df.reset_index(inplace=True)

# %%
lo=df[(df['City']=='Beijing')&(df['Edition']==2008)]

# %%
noc=pd.read_csv('/content/Summer Olympic medallists 1896 to 2008 - IOC COUNTRY CODES.csv')

# %%
noc.head()
# Out:
#            Country Int Olympic Committee code ISO code        Country.1
# 0      Afghanistan                        AFG       AF      Afghanistan
# 1          Albania                        ALB       AL          Albania
# 2          Algeria                        ALG       DZ          Algeria
# 3  American Samoa*                        ASA       AS  American Samoa*
# 4          Andorra                        AND       AD          Andorra

# %%
noc.set_index('Int Olympic Committee code',inplace=True)

# %%
noc.head()
# Out:
#                                     Country ISO code        Country.1
# Int Olympic Committee code
# AFG                             Afghanistan       AF      Afghanistan
# ALB                                 Albania       AL          Albania
# ALG                                 Algeria       DZ          Algeria
# ASA                         American Samoa*       AS  American Samoa*
# AND                                 Andorra       AD          Andorra

# %%
medals_2008=lo.NOC.value_counts()

# %%
medals_2008
# Out:
# USA    315
# CHN    184
# AUS    149
# RUS    143
# GER    101
#       ...
# EGY      1
# CMR      1
# PAN      1
# MAS      1
# VEN      1
# Name: NOC, Length: 86, dtype: int64

# %%
noc['medals_2008']=medals_2008

# %%
noc.head()
# Out:
#                                     Country  ... medals_2008
# Int Olympic Committee code                   ...
# AFG                             Afghanistan  ...         1.0
# ALB                                 Albania  ...         NaN
# ALG                                 Algeria  ...         2.0
# ASA                         American Samoa*  ...         NaN
# AND                                 Andorra  ...         NaN
#
# [5 rows x 4 columns]

# %%
noc[noc.medals_2008.isnull()]
# Out:
#                                         Country  ... medals_2008
# Int Olympic Committee code                       ...
# ALB                                     Albania  ...         NaN
# ASA                             American Samoa*  ...         NaN
# AND                                     Andorra  ...         NaN
# ANG                                      Angola  ...         NaN
# ANT                         Antigua and Barbuda  ...         NaN
# ...                                         ...  ...         ...
# URU                                     Uruguay  ...         NaN
# VAN                                     Vanuatu  ...         NaN
# ISV                             Virgin Islands*  ...         NaN
# YEM                                       Yemen  ...         NaN
# ZAM                                      Zambia  ...         NaN
#
# [117 rows x 4 columns]

# %%
for grop_key,group_value in df.groupby('Edition'):
  print(grop_key)
  print(group_value)
type(group_value)
# Out:
# 1896
#        NOC                   Athlete  ... Event_gender   Medal
# 585    GRE          ANDREOU, Joannis  ...            M  Silver
# 596    GRE  ANDRIAKOPOULOS, Nicolaos  ...            M  Silver
# 597    GRE  ANDRIAKOPOULOS, Nicolaos  ...            M    Gold
# 922    GRE    ATHANASOPOULOS, Spyros  ...            M  Silver
# 1466   GBR            BATTEL, Edward  ...            M  Bronze
# ...    ...                       ...  ...          ...     ...
# 28458  GRE        XENAKIS, Thomasios  ...            M  Silver
# 28459  GRE        XENAKIS, Thomasios  ...            M  Silver
# 29165  SUI             ZUTTER, Louis  ...            M  Silver
# 29166  SUI             ZUTTER, Louis  ...            M  Silver
# 29167  SUI             ZUTTER, Louis  ...            M    Gold
#
# [151 rows x 10 columns]
# 1900
#        NOC                Athlete  ... Event_gender   Medal
# 0      ZZX           AABYE, Edgar  ...            M    Gold
# ...

# %%
df.groupby('Edition').size()
# Out:
# Edition
# 1896     151
# 1900     512
# 1904     470
# 1908     804
# 1912     885
# 1920    1298
# 1924     884
# 1928     710
# 1932     615
# 1936     875
# 1948     814
# 1952     889
# 1956     885
# 1960     882
# 1964    1010
# 1968    1031
# 1972    1185
# 1976    1305
# 1980    1387
# 1984    1459
# 1988    1546
# 1992    1705
# 1996    1859
# 2000    2015
# 2004    1998
# 2008    2042
# dtype: int64

# %%
df.groupby(['Edition','NOC','Medal']).agg(['min','max','count'])
# Out:
#                                     Athlete                           ... Event_gender
#                                         min                      max  ...          max count
# Edition NOC Medal                                                     ...
# 1896    AUS Gold               FLACK, Edwin             FLACK, Edwin  ...            M     2
#         AUT Bronze            SCHMAL, Adolf            SCHMAL, Adolf  ...            M     2
#             Gold              NEUMANN, Paul            SCHMAL, Adolf  ...            M     2
#             Silver         HERSCHMANN, Otto         HERSCHMANN, Otto  ...            M     1
#         DEN Bronze            JENSEN, Viggo          NIELSEN, Holger  ...            M     3
# ...                                     ...                      ...  ...          ...   ...
# 2008    UZB Silver        TANGRIEV, Abdullo           TIGIEV, Soslan  ...            M     2
# ...

# %%
df.groupby(['Edition','NOC','Medal']).size()
# Out:
# Edition  NOC  Medal
# 1896     AUS  Gold      2
#          AUT  Bronze    2
#               Gold      2
#               Silver    1
#          DEN  Bronze    3
#                        ..
# 2008     UZB  Silver    2
#          VEN  Bronze    1
#          VIE  Silver    1
#          ZIM  Gold      1
#               Silver    3
# Length: 2356, dtype: int64

# %%
df.groupby(['Edition','NOC','Medal']).agg({'Edition':['min','max','count']})
# Out:
#                    Edition
#                        min   max count
# Edition NOC Medal
# 1896    AUS Gold      1896  1896     2
#         AUT Bronze    1896  1896     2
#             Gold      1896  1896     2
#             Silver    1896  1896     1
#         DEN Bronze    1896  1896     3
# ...                    ...   ...   ...
# 2008    UZB Silver    2008  2008     2
#         VEN Bronze    2008  2008     1
#         VIE Silver    2008  2008     1
#         ZIM Gold      2008  2008     1
#             Silver    2008  2008     3
#
# [2356 rows x 3 columns]

# %%
df.loc[df['Athlete']=='LEWIS, Carl'].groupby('Athlete').agg({'Edition':['min','max','count']})
# Out:
#             Edition
#                 min   max count
# Athlete
# LEWIS, Carl    1984  1996    10

# %%
df.groupby('Edition').size().plot()

# %%
df.groupby('NOC').agg({'Edition':['count','min','max']})
# Out:
#     Edition
#       count   min   max
# NOC
# AFG       1  2008  2008
# AHO       1  1988  1988
# ALG      14  1984  2008
# ANZ      29  1908  1912
# ARG     239  1924  2008
# ..      ...   ...   ...
# VIE       2  2000  2008
# YUG     435  1924  2000
# ZAM       2  1984  1996
# ZIM      23  1980  2008
# ZZX      48  1896  1904
#
# [138 rows x 3 columns]

# %%
mw=df[(df['Edition']==2008)& (df['Event']=='100m')|(df['Event']=='200m')]

# %%
mw.head()
# Out:
#       NOC              Athlete  ... Event_gender   Medal
# 725   GBR  APPLEGARTH, William  ...            M  Bronze
# 1140  USA  BAKER, Walter Thane  ...            M  Silver
# 1141  USA  BAKER, Walter Thane  ...            M  Bronze
# 1249  USA       BAPTISTE, Kirk  ...            M  Silver
# 1454  USA    BATES, Michael D.  ...            M  Bronze
#
# [5 rows x 10 columns]

# %%
g=mw.groupby(['NOC','Gender','Discipline','Event']).size()

# %%
df_=g.unstack(['Discipline','Event'])

# %%
df_.stack('Event')
# Out:
# Discipline        Athletics
# NOC Gender Event
# AUS Men    200m         2.0
#     Women  200m         7.0
# BAH Women  200m         2.0
# BRA Men    200m         1.0
# CAN Men    200m         2.0
# EUA Women  200m         2.0
# FRA Men    200m         1.0
#     Women  200m         1.0
# FRG Women  200m         1.0
# GBR Men    200m         6.0
#     Women  200m         2.0
# GDR Women  200m         5.0
# GER Men    200m         1.0
# GRE Men    200m         1.0
# IND Men    200m         1.0
# ITA Men    200m         3.0
# JAM Men    100m         1.0
#            200m         3.0
#     Women  100m         3.0
#            200m        10.0
# NAM Men    200m         2.0
# NED Men    200m         1.0
#     Women  200m         2.0
# NGR Women  200m         1.0
# PAN Men    200m         1.0
# POL Women  200m         3.0
# SRI Women  200m         1.0
# TRI Men    100m         1.0
#            200m         3.0
# URS Men    200m         1.0
#     Women  200m         2.0
# ...

# %%
df_.unstack('Gender')
# Out:
# Discipline Athletics
# Event           200m       100m
# Gender           Men Women  Men Women
# NOC
# AUS              2.0   7.0  NaN   NaN
# BAH              NaN   2.0  NaN   NaN
# BRA              1.0   NaN  NaN   NaN
# CAN              2.0   NaN  NaN   NaN
# EUA              NaN   2.0  NaN   NaN
# FRA              1.0   1.0  NaN   NaN
# FRG              NaN   1.0  NaN   NaN
# GBR              6.0   2.0  NaN   NaN
# GDR              NaN   5.0  NaN   NaN
# GER              1.0   NaN  NaN   NaN
# GRE              1.0   NaN  NaN   NaN
# IND              1.0   NaN  NaN   NaN
# ITA              3.0   NaN  NaN   NaN
# JAM              3.0  10.0  1.0   3.0
# NAM              2.0   NaN  NaN   NaN
# NED              1.0   2.0  NaN   NaN
# NGR              NaN   1.0  NaN   NaN
# PAN              1.0   NaN  NaN   NaN
# POL              NaN   3.0  NaN   NaN
# SRI              NaN   1.0  NaN   NaN
# TRI              3.0   NaN  1.0   NaN
# URS              1.0   2.0  NaN   NaN
# ...

# %%
mw=df[(df['Medal']=='Gold')& (df['NOC']=='USA')]

# %%
mw.groupby(['Edition','Gender']).size().sort_values().unstack('Gender',fill_value=0).plot(figsize=(8,6));

# %%
ath_mostmedals = df.groupby(['Athlete','Medal']).size().unstack('Medal',fill_value=0)

# %%
ath_mostmedals.sort_values(['Gold','Silver','Bronze'],ascending=False)[['Gold','Silver','Bronze']].head().plot(kind='bar')
